# %% [markdown]
# <a href="https://colab.research.google.com/github/shevank/Manejo-de-base-de-datos/blob/main/7ma_Ejercicio_de_Histogramas_y_Diagramas_de_caja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
filename = '/content/drive/MyDrive/Data Science 2022/catsvdogs.xlsx'
df = pd.read_excel(filename)
df
# Out:
#                 Location  Number of Households (in 1000)  \
# 0                Alabama                            1828
# 1                Arizona                            2515
# 2               Arkansas                            1148
# 3             California                           12974
# 4               Colorado                            1986
# 5            Connecticut                            1337
# 6               Delaware                             334
# 7   District of Columbia                             287
# 8                Florida                            7609
# 9                Georgia                            3798
# 10                 Idaho                             568
# 11              Illinois                            5026
# 12               Indiana                            2478
# 13                  Iowa                            1219
# 14                Kansas                            1133
# ...

# %%
#Para establecer Employee number como index uso el siguiente código
df = df.set_index('Location')
df
# Out:
#                       Number of Households (in 1000)  \
# Location
# Alabama                                         1828
# Arizona                                         2515
# Arkansas                                        1148
# California                                     12974
# Colorado                                        1986
# Connecticut                                     1337
# Delaware                                         334
# District of Columbia                             287
# Florida                                         7609
# Georgia                                         3798
# Idaho                                            568
# Illinois                                        5026
# Indiana                                         2478
# Iowa                                            1219
# Kansas                                          1133
# Kentucky                                        1777
# ...

# %%
df.shape
# Out:
# (49, 11)

# %%
df['Percentage of Dog Owners'].hist(bins=20)
plt.show()

# %%
#Me muestra que la mayoría de personas que tiene perros se encuentra en North Dakota

# %%
df['Percentage of Cat Owners'].hist(bins=30)
plt.show()

# %%
#Me muestra que la gran mayoría de dueños de gatos se encuentran en North dakota aproximadamente.
