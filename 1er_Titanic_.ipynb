# %% [markdown]
# <a href="https://colab.research.google.com/github/shevank/Manejo-de-base-de-datos/blob/main/1er_Titanic_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Descarga los datos para este ejercicio aquí.
#
# Este es un conjunto de datos de Kaggle que se suele usar como introducción para las competencias de Kaggle. El objetivo usual de este conjunto de datos es predecir la supervivencia en el Titanic basándose en las características de los pasajeros. Para este ejercicio, estarás contestando preguntas sobre el conjunto de datos.
#
# Tu tarea es escribir código para contestar todas las siguientes preguntas:
#
# Muestra la cabecera de la trama de datos
# ¿Cuál es el porcentaje de personas que sobrevivió? (pista: encuentra la media de la columna de supervivencia)
# ¿Cuántos de cada sexo sobrevivieron?
# ¿Cuál es el porcentaje de gente que sobrevivió que pagó un pasaje de menos de 10?
# ¿Cuál es la edad promedio de quienes no sobrevivieron?
# ¿Cuál es la edad promedio de quienes sobrevivieron?
# ¿Cuál es la edad promedio de quienes sobrevivieron y no sobrevivieron agrupados por sexo?

# %%
data = "/content/drive/MyDrive/Data Science 2022/titanic/titanic.csv"
import pandas as pd 
df = pd.read_csv(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
#Cabecera de la trama de datos 
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
filtroid148 = df['PassengerId']== 148
df[filtroid148]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 147          148         0       3  Ford, Miss. Robina Maggie "Ruby"  female
#
#      Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 147  9.0      2      2  W./C. 6608  34.375   NaN        S

# %%
#Aqui filtro quienes sobrevivieron
filtro_sobrevivieron = df['Survived'] == 1
df[filtro_sobrevivieron]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
dt= df[filtro_sobrevivieron]
dt.head(300)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 759          760         1       1
# 762          763         1       3
# 763          764         1       1
# 765          766         1       1
# 774          775         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
dt.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# PassengerId    444.368421
# Survived         1.000000
# Pclass           1.950292
# Age             28.343690
# SibSp            0.473684
# Parch            0.464912
# Fare            48.395408
# dtype: float64

# %%
alive= df.groupby(['Survived']).count()
alive
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
#Quiero saber si este es el método para obtener los datos faltantes 
dr = df.isna().sum()
dr
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Eliminando todos los valores faltantes, quiero saber si así funciona
df.loc[:,:].dropna(how = 'any')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Aqui trato de mostrar los valores por clase y supervivencia
df.groupby(['Pclass', 'Survived'])['PassengerId'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %%
#Aqui trato de mostrar los valores por clase y supervivencia acá tengo duda respecto a que solo piden mostrar los sobrevivientes no los q murieron 
df[filtro_sobrevivieron].groupby(['Sex', 'Survived'])['PassengerId'].count()
# Out:
# Sex     Survived
# female  1           233
# male    1           109
# Name: PassengerId, dtype: int64

# %%
# Aqui tengo el porcentaje de personas que sobrevivió
filtro_sobrevivieron.mean()
# Out:
# 0.3838383838383838

# %%
filtro_fare= df['Fare'] < 10 
df[filtro_fare]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris    male
# 2              3         1       3          Heikkinen, Miss. Laina  female
# 4              5         0       3        Allen, Mr. William Henry    male
# 5              6         0       3                Moran, Mr. James    male
# 12            13         0       3  Saundercock, Mr. William Henry    male
# ..           ...       ...     ...                             ...     ...
# 877          878         0       3            Petroff, Mr. Nedelio    male
# 878          879         0       3              Laleff, Mr. Kristo    male
# 881          882         0       3              Markun, Mr. Johann    male
# 884          885         0       3          Sutehall, Mr. Henry Jr    male
# 890          891         0       3             Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# ...

# %%
menos10 = df[filtro_sobrevivieron & filtro_fare] 
#menos10['Fare'].mean()
#menos10['Fare'].count() / df['Fare'].count()

# %%
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 2              3         1       3            Heikkinen, Miss. Laina  female
# 19            20         1       3           Masselmani, Mrs. Fatima  female
# 22            23         1       3       McGowan, Miss. Anna "Annie"  female
# 28            29         1       3     O'Dwyer, Miss. Ellen "Nellie"  female
# 32            33         1       3          Glynn, Miss. Mary Agatha  female
# ..           ...       ...     ...                               ...     ...
# 804          805         1       3           Hedman, Mr. Oskar Arvid    male
# 821          822         1       3                 Lulic, Mr. Nikola    male
# 828          829         1       3      McCormack, Mr. Thomas Joseph    male
# 855          856         1       3        Aks, Mrs. Sam (Leah Rosen)  female
# 875          876         1       3  Najib, Miss. Adele Kiamie "Jane"  female
#
# ...

# %%
menos10['Survived'].count()
# Out:
# 67

# %%
df['Survived'].count()
# Out:
# 891

# %%
#Aqui filtro quienes no sobrevivieron
filtro_nosobrevivieron = df['Survived'] == 0
df[filtro_nosobrevivieron]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df[filtro_sobrevivieron]['Age'].mean()
# Out:
# 28.343689655172415

# %%
df[~filtro_sobrevivieron]['Age'].mean()
# Out:
# 30.62617924528302

# %%
df[filtro_sobrevivieron]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(['Sex', 'Survived'])[['Age']].mean()
# Out:
#                        Age
# Sex    Survived
# female 0         25.046875
#        1         28.847716
# male   0         31.618056
#        1         27.276022

# %%
df[filtro_sobrevivieron].groupby(['Sex'])[['Age']].mean()
# Out:
#               Age
# Sex
# female  28.847716
# male    27.276022

# %%
df[~filtro_sobrevivieron].groupby(['Sex'])[['Age']].mean()
# Out:
#               Age
# Sex
# female  25.046875
# male    31.618056
