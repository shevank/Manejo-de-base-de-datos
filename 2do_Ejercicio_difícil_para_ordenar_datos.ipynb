# %% [markdown]
# <a href="https://colab.research.google.com/github/shevank/Manejo-de-base-de-datos/blob/main/2do_Ejercicio_dif%C3%ADcil_para_ordenar_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive') #  force_remount=True , pide eso no sé porqué
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Usando el archivo GDP.csv realiza la tarea de manipular los datos para ordenarlos. El resultado debería ser una estructura de datos Pandas con las siguientes columnas:
#
# Nombre del País
# Código del País
# Años
# PIB
# Para comenzar con esta tarea, aquí hay algunas cosas que deberías hacer:
#
#
# Importar librerías
#
# Cargar el conjunto de datos
#
# Haz la lectura del archivo GDP.csv en la carpeta de datos (que quizá tengas que crear si no existe) como una trama de datos Pandas llamada df. Pista: deberías considerar mirar el archivo antes de hacer la lectura. Quizá necesites leer los parámetros del método que utiliza para realizar la lectura del archivo csv.
#
# Tarea
#
# Nombre del País
# Código del País
# Años
# PIB
# Es muy recomendado que uses la hoja de referencia pandas pydata.
#
# Haz una lista de las columnas que quieres mantener y el resto se volverán filas.
#
# Desde aquí, puedes responder preguntas sobre el conjunto de datos si quieres.

# %%
filename = '/content/drive/MyDrive/Data Science 2022/excel de pruebas/GDP.csv'     # csv
df = pd.read_csv(filename, skiprows = 4)   # csv
df
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            133 non-null    float64
#  5   1961            133 non-null    float64
#  6   1962            135 non-null    float64
#  7   1963            135 non-null    float64
#  8   1964            135 non-null    float64
#  9   1965            145 non-null    float64
#  10  1966            146 non-null    float64
#  11  1967            149 non-null    float64
#  12  1968            153 non-null    float64
#  13  1969            153 non-null    float64
#  14  1970            162 non-null    float64
#  15  1971            163 non-null    float64
#  16  1972            163 non-null    float64
# ...

# %%
dt = df.melt(id_vars =['Country Name','Country Code' ], value_vars =['1960',
'1961',
'1962',
'1963',
'1964',
'1965',
'1966',
'1967',
'1968',
'1969',
'1970',
'1971',
'1972',
'1973',
'1974',
'1975',
'1976',
'1977',
'1978',
'1979',
'1980',
'1981',
'1982',
'1983',
'1984',
'1985',
'1986',
'1987',
'1988',
'1989',
'1990',
'1991',
'1992',
'1993',
'1994',
'1995',
'1996',
'1997',
'1998',
'1999',
'2000',
'2001',
'2002',
'2003',
'2004',
'2005',
'2006',
'2007',
'2008',
'2009',
'2010',
'2011',
'2012',
'2013',
'2014',
'2015',
'2016',
'2017'],var_name ='Años', value_name ='PIB')

# %%
dt
# Out:
#        Country Name Country Code  Años           PIB
# 0             Aruba          ABW  1960           NaN
# 1       Afghanistan          AFG  1960  5.377778e+08
# 2            Angola          AGO  1960           NaN
# 3           Albania          ALB  1960           NaN
# 4           Andorra          AND  1960           NaN
# ...             ...          ...   ...           ...
# 15307        Kosovo          XKX  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017           NaN
# 15309  South Africa          ZAF  2017  3.494193e+11
# 15310        Zambia          ZMB  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]

# %%
dt['PIB'].isna()
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 15307    False
# 15308     True
# 15309    False
# 15310    False
# 15311    False
# Name: PIB, Length: 15312, dtype: bool

# %%
dt['PIB'].isna().dropna()
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 15307    False
# 15308     True
# 15309    False
# 15310    False
# 15311    False
# Name: PIB, Length: 15312, dtype: bool
